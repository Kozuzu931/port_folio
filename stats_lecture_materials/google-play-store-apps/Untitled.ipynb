# %%
import pandas as pd
import scipy.stats as ss
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("AppleStore.csv", names=["master_id","id","track_name","size_bytes","currency","price","r"])
display(df)
# Out:
#                                                                                                                                                               master_id  \
# NaN     id         track_name                                         size_bytes currency price rating_count_tot rating_count_ver user_rating user_rating_ver       ver
# 1.0     281656475  PAC-MAN Premium                                    100788224  USD      3.99  21292            26               4           4.5                 6.3.5
# 2.0     281796108  Evernote - stay organized                          158578688  USD      0     161065           26               4           3.5                 8.2.2
# 3.0     281940292  WeatherBug - Local Weather, Radar, Maps, Alerts    100524032  USD      0     188583           2822             3.5         4.5                 5.0.0
# ...

# %%
df.columns = ["meta_id","id","track_name","size_bytes","currency","price","r"]
display(df)
# Out:
#                                                                                                                                                                 meta_id  \
# NaN     id         track_name                                         size_bytes currency price rating_count_tot rating_count_ver user_rating user_rating_ver       ver
# 1.0     281656475  PAC-MAN Premium                                    100788224  USD      3.99  21292            26               4           4.5                 6.3.5
# 2.0     281796108  Evernote - stay organized                          158578688  USD      0     161065           26               4           3.5                 8.2.2
# 3.0     281940292  WeatherBug - Local Weather, Radar, Maps, Alerts    100524032  USD      0     188583           2822             3.5         4.5                 5.0.0
# ...

# %%
df.columns
# Out:
# Index(['meta_id', 'id', 'track_name', 'size_bytes', 'currency', 'price', 'r'], dtype='object')
