# %%
import scipy.stats as ss
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data/stats2_1_1.csv", comment="#")

# %%
data
# Out:
#     CrimeRate  Youth  Southern  Education  ExpenditureYear0  LabourForce  \
# 0        45.5    135         0       12.4                69          540
# 1        52.3    140         0       10.9                55          535
# 2        56.6    157         1       11.2                47          512
# 3        60.3    139         1       11.9                46          480
# 4        64.2    126         0       12.2               106          599
# 5        67.6    128         0       13.5                67          624
# 6        70.5    130         0       14.1                63          641
# 7        73.2    143         0       12.9                66          537
# 8        75.0    141         0       12.9                56          523
# 9        78.1    133         0       11.4                51          599
# 10       79.8    142         1       12.9                45          533
# 11       82.3    123         0       12.5                97          526
# ...

# %%
data_CrimeRate = data["CrimeRate"]

# %%
data_CrimeRate.describe()
# Out:
# count     47.000000
# mean     102.808511
# std       28.893266
# min       45.500000
# 25%       82.700000
# 50%      103.000000
# 75%      120.650000
# max      161.800000
# Name: CrimeRate, dtype: float64

# %%
print("歪度: {0}\n 尖度: {1}".format(data_CrimeRate.skew(), data_CrimeRate.kurt()))
# Out:
# 歪度: 0.1418895340574679
#  尖度: -0.5375374672926232

# %%
plt.hist(data_CrimeRate)
# Out:
# (array([3., 3., 5., 5., 8., 9., 4., 4., 3., 3.]),
#  array([ 45.5 ,  57.13,  68.76,  80.39,  92.02, 103.65, 115.28, 126.91,
#         138.54, 150.17, 161.8 ]),
#  <a list of 10 Patch objects>)
