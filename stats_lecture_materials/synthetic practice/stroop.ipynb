# %%
import numpy as np
import scipy.stats as ss
import statsmodels.api as sm
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data/csv all_results_ex2.csv")

# %%
data
# Out:
#      response time correct response answered response  Unnamed: 3
# 0             2538                n                 n         NaN
# 1             1770                y                 y         NaN
# 2            21433                y                 y         NaN
# 3              993                n                 n         NaN
# 4              873                y                 y         NaN
# 5             1362                y                 y         NaN
# 6              889                n                 n         NaN
# 7             1234                n                 n         NaN
# 8             3138                y                 y         NaN
# 9             1222                y                 y         NaN
# 10            1449                n                 n         NaN
# 11            1308                y                 y         NaN
# 12            1776                y                 y         NaN
# ...

# %%
data_correct = data[data["correct response"] == data["answered response"]]
data_uncorrect = data[data["correct response"] != data["answered response"]]

# %%
ss.moment
