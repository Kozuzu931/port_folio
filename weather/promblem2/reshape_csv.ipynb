# %%
import pandas as pd

# %%
data = pd.read_csv("data.csv")
pd.set_option("display.max_rows", 1500)

# %%
data
# Out:
#          年  月   日   時  気温(℃)  気温()  降水量(mm)  降水量(1)  降水量(2)  日照時間(時間)  \
# 0     2018  1   1   1    1.5     8      0.0       1       8       0.0
# 1     2018  1   1   2    1.0     8      0.0       1       8       0.0
# 2     2018  1   1   3    1.2     8      0.0       1       8       0.0
# 3     2018  1   1   4    0.6     8      0.0       1       8       0.0
# 4     2018  1   1   5    1.9     8      0.0       1       8       0.0
# 5     2018  1   1   6    1.6     8      0.0       1       8       0.0
# 6     2018  1   1   7    1.5     8      0.0       1       8       0.0
# 7     2018  1   1   8    2.7     8      0.0       1       8       0.5
# 8     2018  1   1   9    5.5     8      0.0       1       8       1.0
# 9     2018  1   1  10    8.1     8      0.0       1       8       1.0
# 10    2018  1   1  11   10.8     8      0.0       1       8       1.0
# 11    2018  1   1  12   12.2     8      0.0       1       8       1.0
# ...

# %%
data = data.drop(columns=["気温()", "降水量(1)", "降水量(2)", "日照時間(1)", "日照時間(2)"])

# %%
data
# Out:
#          年  月   日   時  気温(℃)  降水量(mm)  日照時間(時間)
# 0     2018  1   1   1    1.5      0.0       0.0
# 1     2018  1   1   2    1.0      0.0       0.0
# 2     2018  1   1   3    1.2      0.0       0.0
# 3     2018  1   1   4    0.6      0.0       0.0
# 4     2018  1   1   5    1.9      0.0       0.0
# 5     2018  1   1   6    1.6      0.0       0.0
# 6     2018  1   1   7    1.5      0.0       0.0
# 7     2018  1   1   8    2.7      0.0       0.5
# 8     2018  1   1   9    5.5      0.0       1.0
# 9     2018  1   1  10    8.1      0.0       1.0
# 10    2018  1   1  11   10.8      0.0       1.0
# 11    2018  1   1  12   12.2      0.0       1.0
# 12    2018  1   1  13   12.3      0.0       1.0
# 13    2018  1   1  14   12.4      0.0       1.0
# 14    2018  1   1  15   11.7      0.0       1.0
# 15    2018  1   1  16   10.5      0.0       0.6
# 16    2018  1   1  17    9.3      0.0       0.3
# 17    2018  1   1  18    8.0      0.0       0.0
# 18    2018  1   1  19    7.3      0.0       0.0
# ...

# %%
data.to_csv("data/Tokyo_wethear_adjust.csv")
